# %%
# Package imports
# importing matplotlib module
from matplotlib import pyplot as plt

# importing sympy for symbolic mantipulation
import sympy as sp

# import numpy for math and stuff
import numpy as np

# %% [markdown]
# ## Part 1: Numerical Practice
# The vast majority of scientific computation is done numerically (as opped to symbolically). Try to complete the following tasks.
#
# 1. Consider the ideal gas law, pv = nRT. Make a list of 60 evely spaced volumes from 50 to 2500 Liters.
# Using a for loop, calculate the pressure for 1 mole of gas at 300 K for all the volumes and print the results in a table-like format.
#
# 2. Make a plot of your data using matplotlib, pressure as a function of volume (this means volume on the x-axis, pressure on the y-axis).
#
# 3. Use the numpy trapezoid function (`np.trapezoid` or `np.trapz` depending on the version of numpy you have installed) to find the area under the curve. You may want to look at the docs for clarificaion.
# (note that the order of the variables list determines the intgration limits)
#
# 4. Now, instead of having just one temperature, make a list of the temperatures: 100, 200, 300, 400 (Kelvin).
# Calculate the data for the pV curve at all four temperatures and show them all on the same graph.
# You will need to use a nested for loop to do this.
# Make your outer for loop count over the temperatures and your inner for loop count over the pressures.

# %%
# Code box for question 1
# start by defining constant variables of moles, temperature, and the gas constant (use values provided)
n = 1
T = 300
R = 0.082057366080960 # (L atm) / (K mol)

# Your codes goes here

# %%
# Code box for Question 2
# Make a nice plot of pressure vs. volume

# %%
# Code box for Question 3
# Use numpy to numerically integrate, and print the result

# %%
# Code box for Question 4

# List of temperatures
temperatures = [100, 200, 300, 400]

# Your code goes here

# %% [markdown]
# ## Part 2: Sympy Practice
# 1. On paper, symbolically solve the ideal gas law for pressure as a function of volume. Integrate your expression from some inital volume $V_o$ to some final volume $V_f$.
#
# 2. Set up the ideal gas law using sympy, solved for pressure, as a symbolic function.
#
# 3. Integrate the function with respect to p. Confirm that it matches your hand written expression.
#
# 4. Now do a definite integral. Integrate pressure with respect to volume from 100 to 2000 Liters.
#
# 5. Now use the subs function to substitute in n=1, R=0.0821, and K=300 into your integrated expression.
#
# Use the sympy subs() function to evaluate this to a decimal answer.
# You should get close to, but not exactly what you calculated numerically using trapz in Part 1, since trapz is a
# numerical approximation of analytical integration.

# %%
# Your code goes here
# Add additional code boxes as needed
